# %%
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras import models
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
DATASET_DIR = './data'
class_names = ['yes', 'no']
image_size = (128, 128)
batch_size = 32

checkpoint_path = "./model_checkpoints/"
checkpoint_name = "model-{epoch:02d}-{val_accuracy:.4f}.h5"
checkpoint_filepath = os.path.join(checkpoint_path, checkpoint_name)

# %%
# Create the tf datasets
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_DIR + '/train/',
    labels='inferred', 
    label_mode='binary',  
    class_names=class_names,
    color_mode='rgb',  
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True, 
    seed=123,  
    validation_split=0.2,  # Split dataset into training and validation
    subset='training'  
)


validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_DIR + '/train/',
    labels='inferred',
    label_mode='binary',
    class_names=class_names,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation'  
)

test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_DIR + '/test/',
    labels='inferred',
    label_mode='binary',
    class_names=class_names,
    color_mode='rgb',
    batch_size=batch_size,
    image_size=image_size,
    shuffle=True,
    seed=123,
)
# Out:
# Found 222 files belonging to 2 classes.
# Using 178 files for training.
# Found 222 files belonging to 2 classes.
# Using 44 files for validation.
# Found 31 files belonging to 2 classes.

# %%
model = models.Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=image_size + (3,)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    Flatten(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Use 'sigmoid' activation for binary classification
])

# %%
# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  
    patience=20, 
    restore_best_weights=True  
)

checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,  
    monitor='val_accuracy', 
    save_best_only=True,
    save_weights_only=False,  # Save the entire model
    mode='max',
    verbose=1
)

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy', 
              metrics=['accuracy'])


# Display the model summary
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_14 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_15 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_16 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_24 (Conv2D)          (None, 12, 12, 256)       295168
#
#  flatten_7 (Flatten)         (None, 36864)             0
#
#  dropout_4 (Dropout)         (None, 36864)             0
#
#  dense_14 (Dense)            (None, 64)                2359360
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 2747841 (10.48 MB)
# Trainable params: 2747841 (10.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,  
    callbacks=[early_stopping, checkpoint_callback] 
)
# Out:
# Epoch 1/100
# 6/6 [==============================] - ETA: 0s - loss: 26.8425 - accuracy: 0.6461
# Epoch 1: val_accuracy improved from -inf to 0.47727, saving model to ./model_checkpoints/model-01-0.4773.h5
# 6/6 [==============================] - 2s 211ms/step - loss: 26.8425 - accuracy: 0.6461 - val_loss: 2.0318 - val_accuracy: 0.4773
# Epoch 2/100
# /Users/armbod/miniforge3/envs/tumour/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6/6 [==============================] - ETA: 0s - loss: 1.6159 - accuracy: 0.6517
# Epoch 2: val_accuracy improved from 0.47727 to 0.75000, saving model to ./model_checkpoints/model-02-0.7500.h5
# 6/6 [==============================] - 1s 186ms/step - loss: 1.6159 - accuracy: 0.6517 - val_loss: 0.5318 - val_accuracy: 0.7500
# Epoch 3/100
# 6/6 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.6910
# Epoch 3: val_accuracy improved from 0.75000 to 0.77273, saving model to ./model_checkpoints/model-03-0.7727.h5
# 6/6 [==============================] - 1s 184ms/step - loss: 0.6257 - accuracy: 0.6910 - val_loss: 0.4984 - val_accuracy: 0.7727
# Epoch 4/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5882 - accuracy: 0.7079
# Epoch 4: val_accuracy did not improve from 0.77273
# 6/6 [==============================] - 1s 180ms/step - loss: 0.5882 - accuracy: 0.7079 - val_loss: 0.5559 - val_accuracy: 0.7727
# Epoch 5/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5809 - accuracy: 0.6854
# Epoch 5: val_accuracy improved from 0.77273 to 0.79545, saving model to ./model_checkpoints/model-05-0.7955.h5
# 6/6 [==============================] - 1s 184ms/step - loss: 0.5809 - accuracy: 0.6854 - val_loss: 0.4820 - val_accuracy: 0.7955
# Epoch 6/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.7191
# Epoch 6: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 199ms/step - loss: 0.5419 - accuracy: 0.7191 - val_loss: 0.5010 - val_accuracy: 0.7727
# Epoch 7/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5152 - accuracy: 0.7303
# Epoch 7: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 198ms/step - loss: 0.5152 - accuracy: 0.7303 - val_loss: 0.4847 - val_accuracy: 0.7955
# Epoch 8/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.7584
# Epoch 8: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 193ms/step - loss: 0.5295 - accuracy: 0.7584 - val_loss: 0.4860 - val_accuracy: 0.7727
# Epoch 9/100
# 6/6 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7584
# Epoch 9: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 203ms/step - loss: 0.5147 - accuracy: 0.7584 - val_loss: 0.5161 - val_accuracy: 0.7955
# Epoch 10/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4569 - accuracy: 0.7921
# Epoch 10: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 189ms/step - loss: 0.4569 - accuracy: 0.7921 - val_loss: 0.5090 - val_accuracy: 0.7727
# Epoch 11/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4323 - accuracy: 0.7640
# Epoch 11: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 179ms/step - loss: 0.4323 - accuracy: 0.7640 - val_loss: 0.5535 - val_accuracy: 0.7955
# Epoch 12/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.7640
# Epoch 12: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 182ms/step - loss: 0.4674 - accuracy: 0.7640 - val_loss: 0.5254 - val_accuracy: 0.7727
# Epoch 13/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.7697
# Epoch 13: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 207ms/step - loss: 0.4690 - accuracy: 0.7697 - val_loss: 0.5567 - val_accuracy: 0.7727
# Epoch 14/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4739 - accuracy: 0.7135
# Epoch 14: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 189ms/step - loss: 0.4739 - accuracy: 0.7135 - val_loss: 0.5583 - val_accuracy: 0.7727
# Epoch 15/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4166 - accuracy: 0.8090
# Epoch 15: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 185ms/step - loss: 0.4166 - accuracy: 0.8090 - val_loss: 0.5768 - val_accuracy: 0.7727
# Epoch 16/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.7640
# Epoch 16: val_accuracy did not improve from 0.79545
# 6/6 [==============================] - 1s 202ms/step - loss: 0.4398 - accuracy: 0.7640 - val_loss: 0.5703 - val_accuracy: 0.7955
# Epoch 17/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.7865
# Epoch 17: val_accuracy improved from 0.79545 to 0.84091, saving model to ./model_checkpoints/model-17-0.8409.h5
# 6/6 [==============================] - 1s 205ms/step - loss: 0.4084 - accuracy: 0.7865 - val_loss: 0.5112 - val_accuracy: 0.8409
# Epoch 18/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.7921
# Epoch 18: val_accuracy did not improve from 0.84091
# 6/6 [==============================] - 1s 189ms/step - loss: 0.4090 - accuracy: 0.7921 - val_loss: 0.4958 - val_accuracy: 0.7955
# Epoch 19/100
# 6/6 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.7697
# Epoch 19: val_accuracy did not improve from 0.84091
# 6/6 [==============================] - 1s 187ms/step - loss: 0.3898 - accuracy: 0.7697 - val_loss: 0.5865 - val_accuracy: 0.7955
# Epoch 20/100
# 6/6 [==============================] - ETA: 0s - loss: 0.3351 - accuracy: 0.8483
# Epoch 20: val_accuracy did not improve from 0.84091
# 6/6 [==============================] - 1s 178ms/step - loss: 0.3351 - accuracy: 0.8483 - val_loss: 0.5764 - val_accuracy: 0.7955
# Epoch 21/100
# 6/6 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8371
# Epoch 21: val_accuracy did not improve from 0.84091
# 6/6 [==============================] - 1s 185ms/step - loss: 0.3469 - accuracy: 0.8371 - val_loss: 0.5515 - val_accuracy: 0.7727
# Epoch 22/100
# 6/6 [==============================] - ETA: 0s - loss: 0.3833 - accuracy: 0.8539
# Epoch 22: val_accuracy did not improve from 0.84091
# 6/6 [==============================] - 1s 179ms/step - loss: 0.3833 - accuracy: 0.8539 - val_loss: 0.7160 - val_accuracy: 0.7727
# Epoch 23/100
# 6/6 [==============================] - ETA: 0s - loss: 0.2805 - accuracy: 0.8764
# Epoch 23: val_accuracy improved from 0.84091 to 0.86364, saving model to ./model_checkpoints/model-23-0.8636.h5
# 6/6 [==============================] - 1s 183ms/step - loss: 0.2805 - accuracy: 0.8764 - val_loss: 0.5215 - val_accuracy: 0.8636
# Epoch 24/100
# 6/6 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.8820
# Epoch 24: val_accuracy did not improve from 0.86364
# 6/6 [==============================] - 1s 178ms/step - loss: 0.2825 - accuracy: 0.8820 - val_loss: 0.5242 - val_accuracy: 0.8182
# Epoch 25/100
# 6/6 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9213
# Epoch 25: val_accuracy did not improve from 0.86364
# 6/6 [==============================] - 1s 181ms/step - loss: 0.1984 - accuracy: 0.9213 - val_loss: 0.5787 - val_accuracy: 0.8182

# %%
# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(test_dataset)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# Make predictions on the test dataset
predictions = model.predict(test_dataset)
binary_predictions = (predictions > 0.5).astype("int32")

print("Class predictions for the first few samples:")
print(binary_predictions[:5])
# Out:
# 1/1 [==============================] - 0s 91ms/step - loss: 0.4706 - accuracy: 0.9032
# Test Loss: 0.47056296467781067
# Test Accuracy: 0.9032257795333862
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x29eafa020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 99ms/step
# Class probabilities for the first few samples:
# [[0]
#  [1]
#  [0]
#  [0]
#  [1]]

# %%
# Get best checkpoint
checkpoint_files = [f for f in os.listdir(checkpoint_path) if f.endswith('.h5')]

# Sort the checkpoint files based on validation accuracy (assuming the filename convention)
checkpoint_files.sort(key=lambda x: float(x.split('-')[-1][:-3]), reverse=True)

# Get the filename of the checkpoint with the highest validation accuracy
best_checkpoint_file = checkpoint_files[0]

best_checkpoint_path = os.path.join(checkpoint_path, best_checkpoint_file)
model = load_model(best_checkpoint_path)
